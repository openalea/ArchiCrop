# %%
import sys
sys.path.append('../data')
from archi_dict import *

from openalea.archicrop.archicrop import ArchiCrop
from openalea.archicrop.display import build_scene, display_scene
from openalea.archicrop.stand import agronomic_plot, compute_domain, regular, regularband, config_crop_intercrop
from openalea.archicrop.stics_io import read_csv_file_IC

# %%
file_csv = "D:/ArchiCrop_for_STICS-IC_light/2-outputs/simulations_stics_intercrops.csv"

# %%
d = read_csv_file_IC(file_csv)

# %%
d
# Out:
# {'usm_1': {'2.5D': {'maize': {180: {'Date': '2018-06-29',
#      'Thermal time': 0.0,
#      'Thermal time increment': 0.0,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.0,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.0,
#      'Height increment': 0.0,
#      'Incident PAR': 10.26,
#      'Absorbed PAR': 0.0,
#      'N demand': 0.0,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     181: {'Date': '2018-06-30',
#      'Thermal time': 21.0211,
#      'Thermal time increment': 21.0211,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.032,
#      'Leaf area increment': 0.032,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.522,
#      'Height increment': 0.522,
#      'Incident PAR': 9.6216,
#      'Absorbed PAR': 0.0,
#      'N demand': 0.0,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     182: {'Date': '2018-07-01',
#      'Thermal time': 40.1311,
#      'Thermal time increment': 19.11,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.576,
#      'Leaf area increment': 0.544,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.652,
#      'Height increment': 0.13,
#      'Incident PAR': 5.1528,
#      'Absorbed PAR': 0.0001,
#      'N demand': 0.01,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     183: {'Date': '2018-07-02',
#      'Thermal time': 59.5846,
#      'Thermal time increment': 19.4535,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 1.28,
#      'Leaf area increment': 0.704,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.797,
#      'Height increment': 0.145,
#      'Incident PAR': 7.9344,
#      'Absorbed PAR': 0.0003,
#      'N demand': 0.01,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     184: {'Date': '2018-07-03',
#      'Thermal time': 80.4946,
#      'Thermal time increment': 20.91,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 2.208,
#      'Leaf area increment': 0.928,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.978,
#      'Height increment': 0.181,
#      'Incident PAR': 10.3056,
#      'Absorbed PAR': 0.0005,
#      'N demand': 0.01,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     185: {'Date': '2018-07-04',
#      'Thermal time': 101.3339,
#      'Thermal time increment': 20.8393,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 3.392,
#      'Leaf area increment': 1.184,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.218,
#      'Height increment': 0.24,
#      'Incident PAR': 6.7488,
#      'Absorbed PAR': 0.0007,
#      'N demand': 0.01,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     186: {'Date': '2018-07-05',
#      'Thermal time': 120.1938,
#      'Thermal time increment': 18.86,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 4.704,
#      'Leaf area increment': 1.312,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.516,
#      'Height increment': 0.298,
#      'Incident PAR': 10.488,
#      'Absorbed PAR': 0.001,
#      'N demand': 0.0181,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     187: {'Date': '2018-07-06',
#      'Thermal time': 142.0883,
#      'Thermal time increment': 21.8945,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 6.688,
#      'Leaf area increment': 1.984,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.847,
#      'Height increment': 0.331,
#      'Incident PAR': 9.804,
#      'Absorbed PAR': 0.0015,
#      'N demand': 0.024,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     188: {'Date': '2018-07-07',
#      'Thermal time': 163.7983,
#      'Thermal time increment': 21.71,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 9.184,
#      'Leaf area increment': 2.496,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 2.323,
#      'Height increment': 0.476,
#      'Incident PAR': 8.6184,
#      'Absorbed PAR': 0.002,
#      'N demand': 0.029,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     189: {'Date': '2018-07-08',
#      'Thermal time': 183.6967,
#      'Thermal time increment': 19.8984,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 12.032,
#      'Leaf area increment': 2.848,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 2.913,
#      'Height increment': 0.59,
#      'Incident PAR': 8.892,
#      'Absorbed PAR': 0.0026,
#      'N demand': 0.0391,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     190: {'Date': '2018-07-09',
#      'Thermal time': 205.7567,
#      'Thermal time increment': 22.06,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 16.064,
#      'Leaf area increment': 4.032,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 3.584,
#      'Height increment': 0.671,
#      'Incident PAR': 10.6248,
#      'Absorbed PAR': 0.0035,
#      'N demand': 0.0623,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     191: {'Date': '2018-07-10',
#      'Thermal time': 227.8281,
#      'Thermal time increment': 22.0714,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 21.248,
#      'Leaf area increment': 5.184,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 4.507,
#      'Height increment': 0.923,
#      'Incident PAR': 10.3056,
#      'Absorbed PAR': 0.0046,
#      'N demand': 0.0798,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     192: {'Date': '2018-07-11',
#      'Thermal time': 253.2725,
#      'Thermal time increment': 25.4444,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 29.216,
#      'Leaf area increment': 7.968,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 5.662,
#      'Height increment': 1.155,
#      'Incident PAR': 8.0256,
#      'Absorbed PAR': 0.0064,
#      'N demand': 0.0854,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     193: {'Date': '2018-07-12',
#      'Thermal time': 276.5322,
#      'Thermal time increment': 23.2597,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 38.56,
#      'Leaf area increment': 9.344,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 7.354,
#      'Height increment': 1.692,
#      'Incident PAR': 8.8008,
#      'Absorbed PAR': 0.0084,
#      'N demand': 0.1233,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     194: {'Date': '2018-07-13',
#      'Thermal time': 298.2492,
#      'Thermal time increment': 21.717,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 49.536,
#      'Leaf area increment': 10.976,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 9.323,
#      'Height increment': 1.969,
#      'Incident PAR': 8.2536,
#      'Absorbed PAR': 0.0108,
#      'N demand': 0.1482,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     195: {'Date': '2018-07-14',
#      'Thermal time': 323.0829,
#      'Thermal time increment': 24.8337,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 66.144,
#      'Leaf area increment': 16.608,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 11.612,
#      'Height increment': 2.289,
#      'Incident PAR': 10.26,
#      'Absorbed PAR': 0.0143,
#      'N demand': 0.2448,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     196: {'Date': '2018-07-15',
#      'Thermal time': 345.2649,
#      'Thermal time increment': 22.182,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 84.768,
#      'Leaf area increment': 18.624,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 14.883,
#      'Height increment': 3.271,
#      'Incident PAR': 3.7848,
#      'Absorbed PAR': 0.0183,
#      'N demand': 0.1159,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     197: {'Date': '2018-07-16',
#      'Thermal time': 363.9749,
#      'Thermal time increment': 18.71,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 103.552,
#      'Leaf area increment': 18.784,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 18.517,
#      'Height increment': 3.634,
#      'Incident PAR': 5.5176,
#      'Absorbed PAR': 0.0223,
#      'N demand': 0.2054,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     198: {'Date': '2018-07-17',
#      'Thermal time': 385.6153,
#      'Thermal time increment': 21.6404,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 131.232,
#      'Leaf area increment': 27.68,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 22.199,
#      'Height increment': 3.682,
#      'Incident PAR': 6.0192,
#      'Absorbed PAR': 0.0282,
#      'N demand': 0.2823,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     199: {'Date': '2018-07-18',
#      'Thermal time': 403.7254,
#      'Thermal time increment': 18.11,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 158.56,
#      'Leaf area increment': 27.328,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 27.272,
#      'Height increment': 5.073,
#      'Incident PAR': 5.472,
#      'Absorbed PAR': 0.034,
#      'N demand': 0.3088,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     200: {'Date': '2018-07-19',
#      'Thermal time': 420.5853,
#      'Thermal time increment': 16.86,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 188.48,
#      'Leaf area increment': 29.92,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 32.272,
#      'Height increment': 5.0,
#      'Incident PAR': 9.12,
#      'Absorbed PAR': 0.0226,
#      'N demand': 0.3412,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     201: {'Date': '2018-07-20',
#      'Thermal time': 439.8933,
#      'Thermal time increment': 19.308,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 230.624,
#      'Leaf area increment': 42.144,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 37.61,
#      'Height increment': 5.338,
#      'Incident PAR': 7.9344,
#      'Absorbed PAR': 0.0308,
#      'N demand': 0.4059,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     202: {'Date': '2018-07-21',
#      'Thermal time': 460.5033,
#      'Thermal time increment': 20.61,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 285.824,
#      'Leaf area increment': 55.2,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 44.592,
#      'Height increment': 6.982,
#      'Incident PAR': 6.7488,
#      'Absorbed PAR': 0.0422,
#      'N demand': 0.473,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     203: {'Date': '2018-07-22',
#      'Thermal time': 479.8633,
#      'Thermal time increment': 19.36,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 347.456,
#      'Leaf area increment': 61.632,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 53.122,
#      'Height increment': 8.53,
#      'Incident PAR': 10.6248,
#      'Absorbed PAR': 0.0576,
#      'N demand': 1.0018,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     204: {'Date': '2018-07-23',
#      'Thermal time': 500.3698,
#      'Thermal time increment': 20.5065,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 426.272,
#      'Leaf area increment': 78.816,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 62.167,
#      'Height increment': 9.045,
#      'Incident PAR': 8.9832,
#      'Absorbed PAR': 0.0742,
#      'N demand': 1.0926,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     205: {'Date': '2018-07-24',
#      'Thermal time': 522.161,
#      'Thermal time increment': 21.7912,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 527.552,
#      'Leaf area increment': 101.28,
#      'Plant senescent leaf area': 0.032,
#      'Senescent leaf area increment': 0.032,
#      'Plant height': 72.81,
#      'Height increment': 10.643,
#      'Incident PAR': 10.26,
#      'Absorbed PAR': 0.096,
#      'N demand': 1.5928,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     206: {'Date': '2018-07-25',
#      'Thermal time': 544.8708,
#      'Thermal time increment': 22.7098,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 654.304,
#      'Leaf area increment': 126.752,
#      'Plant senescent leaf area': 0.032,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 85.215,
#      'Height increment': 12.405,
#      'Incident PAR': 5.472,
#      'Absorbed PAR': 0.1209,
#      'N demand': 1.0909,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     207: {'Date': '2018-07-26',
#      'Thermal time': 562.4808,
#      'Thermal time increment': 17.61,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 763.008,
#      'Leaf area increment': 108.704,
#      'Plant senescent leaf area': 0.032,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 99.137,
#      'Height increment': 13.922,
#      'Incident PAR': 6.5664,
#      'Absorbed PAR': 0.1436,
#      'N demand': 1.5356,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     208: {'Date': '2018-07-27',
#      'Thermal time': 582.1984,
#      'Thermal time increment': 19.7176,
#      'Phenology': 'exponential',
#      'Plant leaf area': 904.096,
#      'Leaf area increment': 141.088,
#      'Plant senescent leaf area': 0.032,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 110.437,
#      'Height increment': 11.3,
#      'Incident PAR': 4.6056,
#      'Absorbed PAR': 0.1703,
#      'N demand': 1.2911,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     209: {'Date': '2018-07-28',
#      'Thermal time': 599.8084,
#      'Thermal time increment': 17.61,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1042.208,
#      'Leaf area increment': 138.112,
#      'Plant senescent leaf area': 0.576,
#      'Senescent leaf area increment': 0.544,
#      'Plant height': 123.373,
#      'Height increment': 12.936,
#      'Incident PAR': 10.032,
#      'Absorbed PAR': 0.1985,
#      'N demand': 3.0835,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     210: {'Date': '2018-07-29',
#      'Thermal time': 619.8137,
#      'Thermal time increment': 20.0054,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1212.576,
#      'Leaf area increment': 170.368,
#      'Plant senescent leaf area': 1.28,
#      'Senescent leaf area increment': 0.704,
#      'Plant height': 134.964,
#      'Height increment': 11.591,
#      'Incident PAR': 5.7912,
#      'Absorbed PAR': 0.2291,
#      'N demand': 2.5375,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     211: {'Date': '2018-07-30',
#      'Thermal time': 637.9353,
#      'Thermal time increment': 18.1216,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1376.64,
#      'Leaf area increment': 164.064,
#      'Plant senescent leaf area': 2.208,
#      'Senescent leaf area increment': 0.928,
#      'Plant height': 147.915,
#      'Height increment': 12.951,
#      'Incident PAR': 7.3416,
#      'Absorbed PAR': 0.2599,
#      'N demand': 3.565,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     212: {'Date': '2018-07-31',
#      'Thermal time': 657.0917,
#      'Thermal time increment': 19.1564,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1564.256,
#      'Leaf area increment': 187.616,
#      'Plant senescent leaf area': 3.392,
#      'Senescent leaf area increment': 1.184,
#      'Plant height': 159.23,
#      'Height increment': 11.315,
#      'Incident PAR': 9.9864,
#      'Absorbed PAR': 0.2928,
#      'N demand': 5.2323,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     213: {'Date': '2018-08-01',
#      'Thermal time': 675.5783,
#      'Thermal time increment': 18.4866,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1756.288,
#      'Leaf area increment': 192.032,
#      'Plant senescent leaf area': 4.704,
#      'Senescent leaf area increment': 1.312,
#      'Plant height': 170.563,
#      'Height increment': 11.333,
#      'Incident PAR': 7.1592,
#      'Absorbed PAR': 0.3267,
#      'N demand': 4.3105,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     214: {'Date': '2018-08-02',
#      'Thermal time': 694.4419,
#      'Thermal time increment': 18.8636,
#      'Phenology': 'exponential',
#      'Plant leaf area': 1958.496,
#      'Leaf area increment': 202.208,
#      'Plant senescent leaf area': 6.688,
#      'Senescent leaf area increment': 1.984,
#      'Plant height': 180.739,
#      'Height increment': 10.176,
#      'Incident PAR': 7.4784,
#      'Absorbed PAR': 0.3641,
#      'N demand': 4.9417,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     215: {'Date': '2018-08-03',
#      'Thermal time': 713.2614,
#      'Thermal time increment': 18.8195,
#      'Phenology': 'exponential',
#      'Plant leaf area': 2170.72,
#      'Leaf area increment': 212.224,
#      'Plant senescent leaf area': 9.184,
#      'Senescent leaf area increment': 2.496,
#      'Plant height': 190.251,
#      'Height increment': 9.512,
#      'Incident PAR': 7.7064,
#      'Absorbed PAR': 0.3952,
#      'N demand': 5.4558,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     216: {'Date': '2018-08-04',
#      'Thermal time': 733.5868,
#      'Thermal time increment': 20.3254,
#      'Phenology': 'exponential',
#      'Plant leaf area': 2414.016,
#      'Leaf area increment': 243.296,
#      'Plant senescent leaf area': 12.032,
#      'Senescent leaf area increment': 2.848,
#      'Plant height': 198.808,
#      'Height increment': 8.557,
#      'Incident PAR': 4.56,
#      'Absorbed PAR': 0.4311,
#      'N demand': 3.7052,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     217: {'Date': '2018-08-05',
#      'Thermal time': 751.2968,
#      'Thermal time increment': 17.71,
#      'Phenology': 'exponential',
#      'Plant leaf area': 2629.408,
#      'Leaf area increment': 215.392,
#      'Plant senescent leaf area': 16.064,
#      'Senescent leaf area increment': 4.032,
#      'Plant height': 206.989,
#      'Height increment': 8.181,
#      'Incident PAR': 10.4424,
#      'Absorbed PAR': 0.4553,
#      'N demand': 7.8607,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     218: {'Date': '2018-08-06',
#      'Thermal time': 770.6186,
#      'Thermal time increment': 19.3218,
#      'Phenology': 'exponential',
#      'Plant leaf area': 2875.616,
#      'Leaf area increment': 246.208,
#      'Plant senescent leaf area': 21.248,
#      'Senescent leaf area increment': 5.184,
#      'Plant height': 213.241,
#      'Height increment': 6.252,
#      'Incident PAR': 8.6184,
#      'Absorbed PAR': 0.4876,
#      'N demand': 7.1595,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     219: {'Date': '2018-08-07',
#      'Thermal time': 791.015,
#      'Thermal time increment': 20.3964,
#      'Phenology': 'exponential',
#      'Plant leaf area': 3144.128,
#      'Leaf area increment': 268.512,
#      'Plant senescent leaf area': 29.216,
#      'Senescent leaf area increment': 7.968,
#      'Plant height': 219.185,
#      'Height increment': 5.944,
#      'Incident PAR': 4.9248,
#      'Absorbed PAR': 0.5224,
#      'N demand': 4.7422,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     220: {'Date': '2018-08-08',
#      'Thermal time': 808.8031,
#      'Thermal time increment': 17.788,
#      'Phenology': 'exponential',
#      'Plant leaf area': 3378.56,
#      'Leaf area increment': 234.432,
#      'Plant senescent leaf area': 38.56,
#      'Senescent leaf area increment': 9.344,
#      'Plant height': 224.544,
#      'Height increment': 5.359,
#      'Incident PAR': 8.2992,
#      'Absorbed PAR': 0.546,
#      'N demand': 7.6141,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     221: {'Date': '2018-08-09',
#      'Thermal time': 827.8491,
#      'Thermal time increment': 19.046,
#      'Phenology': 'exponential',
#      'Plant leaf area': 3637.472,
#      'Leaf area increment': 258.912,
#      'Plant senescent leaf area': 49.536,
#      'Senescent leaf area increment': 10.976,
#      'Plant height': 228.525,
#      'Height increment': 3.981,
#      'Incident PAR': 9.7584,
#      'Absorbed PAR': 0.5722,
#      'N demand': 8.9031,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     222: {'Date': '2018-08-10',
#      'Thermal time': 848.6549,
#      'Thermal time increment': 20.8058,
#      'Phenology': 'exponential',
#      'Plant leaf area': 3942.432,
#      'Leaf area increment': 304.96,
#      'Plant senescent leaf area': 49.536,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 232.156,
#      'Height increment': 3.631,
#      'Incident PAR': 7.98,
#      'Absorbed PAR': 0.6044,
#      'N demand': 4.1416,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     223: {'Date': '2018-08-11',
#      'Thermal time': 868.3198,
#      'Thermal time increment': 19.6649,
#      'Phenology': 'exponential',
#      'Plant leaf area': 4217.824,
#      'Leaf area increment': 275.392,
#      'Plant senescent leaf area': 66.144,
#      'Senescent leaf area increment': 16.608,
#      'Plant height': 235.468,
#      'Height increment': 3.312,
#      'Incident PAR': 6.0648,
#      'Absorbed PAR': 0.6321,
#      'N demand': 3.3372,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     224: {'Date': '2018-08-12',
#      'Thermal time': 888.3715,
#      'Thermal time increment': 20.0518,
#      'Phenology': 'exponential',
#      'Plant leaf area': 4521.344,
#      'Leaf area increment': 303.52,
#      'Plant senescent leaf area': 66.144,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 238.061,
#      'Height increment': 2.593,
#      'Incident PAR': 8.2992,
#      'Absorbed PAR': 0.6566,
#      'N demand': 4.2566,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     225: {'Date': '2018-08-13',
#      'Thermal time': 907.8416,
#      'Thermal time increment': 19.47,
#      'Phenology': 'exponential',
#      'Plant leaf area': 4800.64,
#      'Leaf area increment': 279.296,
#      'Plant senescent leaf area': 84.768,
#      'Senescent leaf area increment': 18.624,
#      'Plant height': 240.249,
#      'Height increment': 2.188,
#      'Incident PAR': 9.9864,
#      'Absorbed PAR': 0.6779,
#      'N demand': 4.7633,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     226: {'Date': '2018-08-14',
#      'Thermal time': 927.1454,
#      'Thermal time increment': 19.3038,
#      'Phenology': 'exponential',
#      'Plant leaf area': 5080.448,
#      'Leaf area increment': 279.808,
#      'Plant senescent leaf area': 103.552,
#      'Senescent leaf area increment': 18.784,
#      'Plant height': 242.001,
#      'Height increment': 1.752,
#      'Incident PAR': 9.348,
#      'Absorbed PAR': 0.7003,
#      'N demand': 4.5045,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     227: {'Date': '2018-08-15',
#      'Thermal time': 946.9749,
#      'Thermal time increment': 19.8295,
#      'Phenology': 'exponential',
#      'Plant leaf area': 5363.744,
#      'Leaf area increment': 283.296,
#      'Plant senescent leaf area': 131.232,
#      'Senescent leaf area increment': 27.68,
#      'Plant height': 243.437,
#      'Height increment': 1.436,
#      'Incident PAR': 5.3352,
#      'Absorbed PAR': 0.7253,
#      'N demand': 2.9613,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     228: {'Date': '2018-08-16',
#      'Thermal time': 967.4574,
#      'Thermal time increment': 20.4825,
#      'Phenology': 'exponential',
#      'Plant leaf area': 5661.728,
#      'Leaf area increment': 297.984,
#      'Plant senescent leaf area': 158.56,
#      'Senescent leaf area increment': 27.328,
#      'Plant height': 244.649,
#      'Height increment': 1.212,
#      'Incident PAR': 10.944,
#      'Absorbed PAR': 0.7396,
#      'N demand': 4.8294,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     229: {'Date': '2018-08-17',
#      'Thermal time': 988.3738,
#      'Thermal time increment': 20.9164,
#      'Phenology': 'exponential',
#      'Plant leaf area': 5967.456,
#      'Leaf area increment': 305.728,
#      'Plant senescent leaf area': 188.48,
#      'Senescent leaf area increment': 29.92,
#      'Plant height': 245.671,
#      'Height increment': 1.022,
#      'Incident PAR': 9.9408,
#      'Absorbed PAR': 0.7603,
#      'N demand': 4.5106,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     230: {'Date': '2018-08-18',
#      'Thermal time': 1010.1657,
#      'Thermal time increment': 21.7919,
#      'Phenology': 'exponential',
#      'Plant leaf area': 6278.944,
#      'Leaf area increment': 311.488,
#      'Plant senescent leaf area': 230.624,
#      'Senescent leaf area increment': 42.144,
#      'Plant height': 246.516,
#      'Height increment': 0.845,
#      'Incident PAR': 7.068,
#      'Absorbed PAR': 0.7824,
#      'N demand': 3.5916,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     231: {'Date': '2018-08-19',
#      'Thermal time': 1029.7644,
#      'Thermal time increment': 19.5987,
#      'Phenology': 'exponential',
#      'Plant leaf area': 6539.84,
#      'Leaf area increment': 260.896,
#      'Plant senescent leaf area': 285.824,
#      'Senescent leaf area increment': 55.2,
#      'Plant height': 247.224,
#      'Height increment': 0.708,
#      'Incident PAR': 8.0712,
#      'Absorbed PAR': 0.7959,
#      'N demand': 3.8919,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     232: {'Date': '2018-08-20',
#      'Thermal time': 1048.0572,
#      'Thermal time increment': 18.2927,
#      'Phenology': 'exponential',
#      'Plant leaf area': 6772.096,
#      'Leaf area increment': 232.256,
#      'Plant senescent leaf area': 347.456,
#      'Senescent leaf area increment': 61.632,
#      'Plant height': 247.738,
#      'Height increment': 0.514,
#      'Incident PAR': 9.348,
#      'Absorbed PAR': 0.8068,
#      'N demand': 4.1924,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     233: {'Date': '2018-08-21',
#      'Thermal time': 1068.0922,
#      'Thermal time increment': 20.035,
#      'Phenology': 'exponential',
#      'Plant leaf area': 7019.872,
#      'Leaf area increment': 247.776,
#      'Plant senescent leaf area': 426.272,
#      'Senescent leaf area increment': 78.816,
#      'Plant height': 248.132,
#      'Height increment': 0.394,
#      'Incident PAR': 6.2016,
#      'Absorbed PAR': 0.8232,
#      'N demand': 3.1701,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     234: {'Date': '2018-08-22',
#      'Thermal time': 1087.8485,
#      'Thermal time increment': 19.7563,
#      'Phenology': 'exponential',
#      'Plant leaf area': 7241.184,
#      'Leaf area increment': 221.312,
#      'Plant senescent leaf area': 527.584,
#      'Senescent leaf area increment': 101.312,
#      'Plant height': 248.486,
#      'Height increment': 0.354,
#      'Incident PAR': 5.9736,
#      'Absorbed PAR': 0.8341,
#      'N demand': 3.0616,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     235: {'Date': '2018-08-23',
#      'Thermal time': 1107.2078,
#      'Thermal time increment': 19.3592,
#      'Phenology': 'repro',
#      'Plant leaf area': 7430.688,
#      'Leaf area increment': 189.504,
#      'Plant senescent leaf area': 654.336,
#      'Senescent leaf area increment': 126.752,
#      'Plant height': 248.769,
#      'Height increment': 0.283,
#      'Incident PAR': 7.9344,
#      'Absorbed PAR': 0.8404,
#      'N demand': 3.6854,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     236: {'Date': '2018-08-24',
#      'Thermal time': 1127.5266,
#      'Thermal time increment': 20.3189,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 225.824,
#      'Plant senescent leaf area': 763.04,
#      'Senescent leaf area increment': 108.704,
#      'Plant height': 248.996,
#      'Height increment': 0.227,
#      'Incident PAR': 10.4424,
#      'Absorbed PAR': 0.8472,
#      'N demand': 4.2144,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     237: {'Date': '2018-08-25',
#      'Thermal time': 1149.7028,
#      'Thermal time increment': 22.1762,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 904.128,
#      'Senescent leaf area increment': 141.088,
#      'Plant height': 249.189,
#      'Height increment': 0.193,
#      'Incident PAR': 9.6672,
#      'Absorbed PAR': 0.8421,
#      'N demand': 3.9695,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     238: {'Date': '2018-08-26',
#      'Thermal time': 1169.6245,
#      'Thermal time increment': 19.9217,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1042.784,
#      'Senescent leaf area increment': 138.656,
#      'Plant height': 249.358,
#      'Height increment': 0.169,
#      'Incident PAR': 3.6024,
#      'Absorbed PAR': 0.8423,
#      'N demand': 1.9041,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     239: {'Date': '2018-08-27',
#      'Thermal time': 1186.0336,
#      'Thermal time increment': 16.4091,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1213.856,
#      'Senescent leaf area increment': 171.072,
#      'Plant height': 249.479,
#      'Height increment': 0.121,
#      'Incident PAR': 7.7976,
#      'Absorbed PAR': 0.8303,
#      'N demand': 3.3494,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     240: {'Date': '2018-08-28',
#      'Thermal time': 1205.8163,
#      'Thermal time increment': 19.7827,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1378.88,
#      'Senescent leaf area increment': 165.024,
#      'Plant height': 249.562,
#      'Height increment': 0.083,
#      'Incident PAR': 3.5568,
#      'Absorbed PAR': 0.8264,
#      'N demand': 1.8084,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     241: {'Date': '2018-08-29',
#      'Thermal time': 1222.7119,
#      'Thermal time increment': 16.8956,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1567.648,
#      'Senescent leaf area increment': 188.768,
#      'Plant height': 249.644,
#      'Height increment': 0.082,
#      'Incident PAR': 6.4752,
#      'Absorbed PAR': 0.9631,
#      'N demand': 3.2097,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     242: {'Date': '2018-08-30',
#      'Thermal time': 1242.6802,
#      'Thermal time increment': 19.9683,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1760.992,
#      'Senescent leaf area increment': 193.344,
#      'Plant height': 249.702,
#      'Height increment': 0.058,
#      'Incident PAR': 9.1656,
#      'Absorbed PAR': 0.9557,
#      'N demand': 2.9545,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     243: {'Date': '2018-08-31',
#      'Thermal time': 1262.2687,
#      'Thermal time increment': 19.5885,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1965.184,
#      'Senescent leaf area increment': 204.192,
#      'Plant height': 249.759,
#      'Height increment': 0.057,
#      'Incident PAR': 4.7424,
#      'Absorbed PAR': 0.9573,
#      'N demand': 2.0399,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     244: {'Date': '2018-09-01',
#      'Thermal time': 1279.4967,
#      'Thermal time increment': 17.228,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 1965.184,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.804,
#      'Height increment': 0.045,
#      'Incident PAR': 8.9832,
#      'Absorbed PAR': 0.9519,
#      'N demand': 2.8672,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     245: {'Date': '2018-09-02',
#      'Thermal time': 1299.908,
#      'Thermal time increment': 20.4113,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 2179.904,
#      'Senescent leaf area increment': 214.72,
#      'Plant height': 249.836,
#      'Height increment': 0.032,
#      'Incident PAR': 6.156,
#      'Absorbed PAR': 0.9513,
#      'N demand': 2.3714,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     246: {'Date': '2018-09-03',
#      'Thermal time': 1319.36,
#      'Thermal time increment': 19.452,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 2426.016,
#      'Senescent leaf area increment': 246.112,
#      'Plant height': 249.868,
#      'Height increment': 0.032,
#      'Incident PAR': 8.5272,
#      'Absorbed PAR': 0.9427,
#      'N demand': 2.7557,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     247: {'Date': '2018-09-04',
#      'Thermal time': 1340.0773,
#      'Thermal time increment': 20.7173,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 2426.016,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.893,
#      'Height increment': 0.025,
#      'Incident PAR': 10.1232,
#      'Absorbed PAR': 0.9407,
#      'N demand': 2.8554,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     248: {'Date': '2018-09-05',
#      'Thermal time': 1360.1009,
#      'Thermal time increment': 20.0236,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 2645.472,
#      'Senescent leaf area increment': 219.456,
#      'Plant height': 249.914,
#      'Height increment': 0.021,
#      'Incident PAR': 8.7096,
#      'Absorbed PAR': 0.7893,
#      'N demand': 2.5147,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     249: {'Date': '2018-09-06',
#      'Thermal time': 1380.3578,
#      'Thermal time increment': 20.257,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 2896.832,
#      'Senescent leaf area increment': 251.36,
#      'Plant height': 249.93,
#      'Height increment': 0.016,
#      'Incident PAR': 10.488,
#      'Absorbed PAR': 0.7825,
#      'N demand': 2.6864,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     250: {'Date': '2018-09-07',
#      'Thermal time': 1399.961,
#      'Thermal time increment': 19.6032,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 3173.344,
#      'Senescent leaf area increment': 276.512,
#      'Plant height': 249.944,
#      'Height increment': 0.014,
#      'Incident PAR': 9.12,
#      'Absorbed PAR': 0.7675,
#      'N demand': 2.4797,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     251: {'Date': '2018-09-08',
#      'Thermal time': 1421.6045,
#      'Thermal time increment': 21.6436,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 3417.12,
#      'Senescent leaf area increment': 243.776,
#      'Plant height': 249.954,
#      'Height increment': 0.01,
#      'Incident PAR': 8.2992,
#      'Absorbed PAR': 0.7531,
#      'N demand': 2.3085,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     252: {'Date': '2018-09-09',
#      'Thermal time': 1440.0188,
#      'Thermal time increment': 18.4143,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 3687.008,
#      'Senescent leaf area increment': 269.888,
#      'Plant height': 249.963,
#      'Height increment': 0.009,
#      'Incident PAR': 5.1528,
#      'Absorbed PAR': 0.7367,
#      'N demand': 1.6211,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     253: {'Date': '2018-09-10',
#      'Thermal time': 1458.1918,
#      'Thermal time increment': 18.173,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 3991.936,
#      'Senescent leaf area increment': 304.928,
#      'Plant height': 249.97,
#      'Height increment': 0.007,
#      'Incident PAR': 6.0192,
#      'Absorbed PAR': 0.7205,
#      'N demand': 1.7809,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     254: {'Date': '2018-09-11',
#      'Thermal time': 1477.8107,
#      'Thermal time increment': 19.6189,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 3991.936,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.975,
#      'Height increment': 0.005,
#      'Incident PAR': 5.5632,
#      'Absorbed PAR': 0.7145,
#      'N demand': 1.6552,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     255: {'Date': '2018-09-12',
#      'Thermal time': 1495.7432,
#      'Thermal time increment': 17.9325,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 4283.968,
#      'Senescent leaf area increment': 292.032,
#      'Plant height': 249.98,
#      'Height increment': 0.005,
#      'Incident PAR': 5.5632,
#      'Absorbed PAR': 0.698,
#      'N demand': 1.6141,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     256: {'Date': '2018-09-13',
#      'Thermal time': 1516.3977,
#      'Thermal time increment': 20.6545,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 4283.968,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.983,
#      'Height increment': 0.003,
#      'Incident PAR': 9.8496,
#      'Absorbed PAR': 0.6915,
#      'N demand': 2.3264,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     257: {'Date': '2018-09-14',
#      'Thermal time': 1537.8454,
#      'Thermal time increment': 21.4476,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 4587.488,
#      'Senescent leaf area increment': 303.52,
#      'Plant height': 249.987,
#      'Height increment': 0.004,
#      'Incident PAR': 3.4656,
#      'Absorbed PAR': 0.6742,
#      'N demand': 1.0413,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     258: {'Date': '2018-09-15',
#      'Thermal time': 1553.2554,
#      'Thermal time increment': 15.41,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 4885.376,
#      'Senescent leaf area increment': 297.888,
#      'Plant height': 249.989,
#      'Height increment': 0.002,
#      'Incident PAR': 10.1688,
#      'Absorbed PAR': 0.6557,
#      'N demand': 2.207,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     259: {'Date': '2018-09-16',
#      'Thermal time': 1572.9809,
#      'Thermal time increment': 19.7255,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 5184.0,
#      'Senescent leaf area increment': 298.624,
#      'Plant height': 249.991,
#      'Height increment': 0.002,
#      'Incident PAR': 4.8336,
#      'Absorbed PAR': 0.6399,
#      'N demand': 1.3031,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     260: {'Date': '2018-09-17',
#      'Thermal time': 1589.7409,
#      'Thermal time increment': 16.76,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 5494.976,
#      'Senescent leaf area increment': 310.976,
#      'Plant height': 249.993,
#      'Height increment': 0.002,
#      'Incident PAR': 9.7584,
#      'Absorbed PAR': 0.6208,
#      'N demand': 2.1014,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     261: {'Date': '2018-09-18',
#      'Thermal time': 1610.0554,
#      'Thermal time increment': 20.3146,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 5820.288,
#      'Senescent leaf area increment': 325.312,
#      'Plant height': 249.994,
#      'Height increment': 0.001,
#      'Incident PAR': 9.4848,
#      'Absorbed PAR': 0.6021,
#      'N demand': 2.02,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     262: {'Date': '2018-09-19',
#      'Thermal time': 1632.8067,
#      'Thermal time increment': 22.7512,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 5820.288,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.995,
#      'Height increment': 0.001,
#      'Incident PAR': 9.804,
#      'Absorbed PAR': 0.5951,
#      'N demand': 2.0276,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     263: {'Date': '2018-09-20',
#      'Thermal time': 1654.9387,
#      'Thermal time increment': 22.1321,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 6155.936,
#      'Senescent leaf area increment': 335.648,
#      'Plant height': 249.996,
#      'Height increment': 0.001,
#      'Incident PAR': 10.1232,
#      'Absorbed PAR': 0.5728,
#      'N demand': 2.0013,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     264: {'Date': '2018-09-21',
#      'Thermal time': 1678.1499,
#      'Thermal time increment': 23.2112,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 6509.568,
#      'Senescent leaf area increment': 353.632,
#      'Plant height': 249.997,
#      'Height increment': 0.001,
#      'Incident PAR': 9.7584,
#      'Absorbed PAR': 0.5495,
#      'N demand': 1.8866,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     265: {'Date': '2018-09-22',
#      'Thermal time': 1701.4972,
#      'Thermal time increment': 23.3473,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 6825.664,
#      'Senescent leaf area increment': 316.096,
#      'Plant height': 249.998,
#      'Height increment': 0.001,
#      'Incident PAR': 7.2048,
#      'Absorbed PAR': 0.5269,
#      'N demand': 1.4578,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     266: {'Date': '2018-09-23',
#      'Thermal time': 1720.8947,
#      'Thermal time increment': 19.3975,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 7119.552,
#      'Senescent leaf area increment': 293.888,
#      'Plant height': 249.998,
#      'Height increment': 0.0,
#      'Incident PAR': 8.0256,
#      'Absorbed PAR': 0.5051,
#      'N demand': 1.5225,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     267: {'Date': '2018-09-24',
#      'Thermal time': 1741.1828,
#      'Thermal time increment': 20.2881,
#      'Phenology': 'repro',
#      'Plant leaf area': 7656.512,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 7119.552,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 249.998,
#      'Height increment': 0.0,
#      'Incident PAR': 8.3448,
#      'Absorbed PAR': 0.4993,
#      'N demand': 1.8832,
#      'Density': 3.125,
#      'Emergence': 181.0}},
#    'sorghum': {180: {'Date': '2018-06-29',
#      'Thermal time': 0.0,
#      'Thermal time increment': 0.0,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.0,
#      'Leaf area increment': 0.0,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.0,
#      'Height increment': 0.0,
#      'Incident PAR': 10.26,
#      'Absorbed PAR': 0.0,
#      'N demand': 0.0,
#      'Density': 3.125,
#      'Emergence': 181.0},
#     181: {'Date': '2018-06-30',
#      'Thermal time': 17.0211,
#      'Thermal time increment': 17.0211,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.0356,
#      'Leaf area increment': 0.0356,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.46,
#      'Height increment': 0.46,
#      'Incident PAR': 9.6216,
#      'Absorbed PAR': 0.0,
#      'N demand': 0.0,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     182: {'Date': '2018-07-01',
#      'Thermal time': 27.8694,
#      'Thermal time increment': 10.8483,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 0.6756,
#      'Leaf area increment': 0.64,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.551,
#      'Height increment': 0.091,
#      'Incident PAR': 5.1528,
#      'Absorbed PAR': 0.0001,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     183: {'Date': '2018-07-02',
#      'Thermal time': 38.9782,
#      'Thermal time increment': 11.1088,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 1.3511,
#      'Leaf area increment': 0.6756,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.617,
#      'Height increment': 0.066,
#      'Incident PAR': 7.9344,
#      'Absorbed PAR': 0.0003,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     184: {'Date': '2018-07-03',
#      'Thermal time': 51.1507,
#      'Thermal time increment': 12.1726,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 2.24,
#      'Leaf area increment': 0.8889,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.694,
#      'Height increment': 0.077,
#      'Incident PAR': 10.3056,
#      'Absorbed PAR': 0.0004,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     185: {'Date': '2018-07-04',
#      'Thermal time': 63.2906,
#      'Thermal time increment': 12.1399,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 3.1644,
#      'Leaf area increment': 0.9244,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.789,
#      'Height increment': 0.095,
#      'Incident PAR': 6.7488,
#      'Absorbed PAR': 0.0006,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     186: {'Date': '2018-07-05',
#      'Thermal time': 74.0209,
#      'Thermal time increment': 10.7303,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 4.0889,
#      'Leaf area increment': 0.9244,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 0.896,
#      'Height increment': 0.107,
#      'Incident PAR': 10.488,
#      'Absorbed PAR': 0.0008,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     187: {'Date': '2018-07-06',
#      'Thermal time': 86.9649,
#      'Thermal time increment': 12.944,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 5.3689,
#      'Leaf area increment': 1.28,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.003,
#      'Height increment': 0.107,
#      'Incident PAR': 9.804,
#      'Absorbed PAR': 0.0011,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     188: {'Date': '2018-07-07',
#      'Thermal time': 99.7993,
#      'Thermal time increment': 12.8344,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 6.7911,
#      'Leaf area increment': 1.4222,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.149,
#      'Height increment': 0.146,
#      'Incident PAR': 8.6184,
#      'Absorbed PAR': 0.0013,
#      'N demand': 0.01,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     189: {'Date': '2018-07-08',
#      'Thermal time': 111.3435,
#      'Thermal time increment': 11.5442,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 8.2133,
#      'Leaf area increment': 1.4222,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.315,
#      'Height increment': 0.166,
#      'Incident PAR': 8.892,
#      'Absorbed PAR': 0.0016,
#      'N demand': 0.0102,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     190: {'Date': '2018-07-09',
#      'Thermal time': 124.4846,
#      'Thermal time increment': 13.1411,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 10.0622,
#      'Leaf area increment': 1.8489,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.484,
#      'Height increment': 0.169,
#      'Incident PAR': 10.6248,
#      'Absorbed PAR': 0.002,
#      'N demand': 0.0146,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     191: {'Date': '2018-07-10',
#      'Thermal time': 137.6629,
#      'Thermal time increment': 13.1783,
#      'Phenology': 'juvenile',
#      'Plant leaf area': 12.1956,
#      'Leaf area increment': 2.1333,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 1.704,
#      'Height increment': 0.22,
#      'Incident PAR': 10.3056,
#      'Absorbed PAR': 0.0024,
#      'N demand': 0.0171,
#      'Density': 2.8125,
#      'Emergence': 181.0},
#     192: {'Date': '2018-07-11',
# ...
#      'Plant height': 169.643,
#      'Height increment': 8.067,
#      'Incident PAR': 5.9736,
#      'Absorbed PAR': 0.1056,
#      'N demand': 0.3516,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     235: {'Date': '2018-08-23',
#      'Thermal time': 694.1879,
#      'Thermal time increment': 13.2034,
#      'Phenology': 'repro',
#      'Plant leaf area': 829.1467,
#      'Leaf area increment': 22.0,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 177.202,
#      'Height increment': 7.559,
#      'Incident PAR': 7.9344,
#      'Absorbed PAR': 0.1058,
#      'N demand': 0.4575,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     236: {'Date': '2018-08-24',
#      'Thermal time': 708.2796,
#      'Thermal time increment': 14.0917,
#      'Phenology': 'repro',
#      'Plant leaf area': 858.1067,
#      'Leaf area increment': 28.96,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 184.176,
#      'Height increment': 6.974,
#      'Incident PAR': 10.4424,
#      'Absorbed PAR': 0.1062,
#      'N demand': 0.5853,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     237: {'Date': '2018-08-25',
#      'Thermal time': 724.0426,
#      'Thermal time increment': 15.763,
#      'Phenology': 'repro',
#      'Plant leaf area': 895.6711,
#      'Leaf area increment': 37.5644,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 191.128,
#      'Height increment': 6.952,
#      'Incident PAR': 9.6672,
#      'Absorbed PAR': 0.1121,
#      'N demand': 0.5522,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     238: {'Date': '2018-08-26',
#      'Thermal time': 737.9104,
#      'Thermal time increment': 13.8677,
#      'Phenology': 'repro',
#      'Plant leaf area': 931.6622,
#      'Leaf area increment': 35.9911,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 198.283,
#      'Height increment': 7.155,
#      'Incident PAR': 3.6024,
#      'Absorbed PAR': 0.118,
#      'N demand': 0.2263,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     239: {'Date': '2018-08-27',
#      'Thermal time': 748.7599,
#      'Thermal time increment': 10.8495,
#      'Phenology': 'repro',
#      'Plant leaf area': 946.6222,
#      'Leaf area increment': 14.96,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 204.027,
#      'Height increment': 5.744,
#      'Incident PAR': 7.7976,
#      'Absorbed PAR': 0.1221,
#      'N demand': 0.4742,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     240: {'Date': '2018-08-28',
#      'Thermal time': 762.6291,
#      'Thermal time increment': 13.8692,
#      'Phenology': 'repro',
#      'Plant leaf area': 978.1867,
#      'Leaf area increment': 31.5644,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 208.168,
#      'Height increment': 4.141,
#      'Incident PAR': 3.5568,
#      'Absorbed PAR': 0.1281,
#      'N demand': 0.238,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     241: {'Date': '2018-08-29',
#      'Thermal time': 774.0059,
#      'Thermal time increment': 11.3768,
#      'Phenology': 'repro',
#      'Plant leaf area': 994.2133,
#      'Leaf area increment': 16.0267,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 213.02,
#      'Height increment': 4.852,
#      'Incident PAR': 6.4752,
#      'Absorbed PAR': 0.1137,
#      'N demand': 0.3687,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     242: {'Date': '2018-08-30',
#      'Thermal time': 788.0941,
#      'Thermal time increment': 14.0883,
#      'Phenology': 'repro',
#      'Plant leaf area': 1019.2,
#      'Leaf area increment': 24.9867,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 216.645,
#      'Height increment': 3.625,
#      'Incident PAR': 9.1656,
#      'Absorbed PAR': 0.1186,
#      'N demand': 0.5401,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     243: {'Date': '2018-08-31',
#      'Thermal time': 801.8971,
#      'Thermal time increment': 13.8029,
#      'Phenology': 'repro',
#      'Plant leaf area': 1056.1689,
#      'Leaf area increment': 36.9689,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 220.712,
#      'Height increment': 4.067,
#      'Incident PAR': 4.7424,
#      'Absorbed PAR': 0.1252,
#      'N demand': 0.3003,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     244: {'Date': '2018-09-01',
#      'Thermal time': 813.6685,
#      'Thermal time increment': 11.7714,
#      'Phenology': 'repro',
#      'Plant leaf area': 1076.9244,
#      'Leaf area increment': 20.7556,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 224.273,
#      'Height increment': 3.561,
#      'Incident PAR': 8.9832,
#      'Absorbed PAR': 0.1305,
#      'N demand': 0.562,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     245: {'Date': '2018-09-02',
#      'Thermal time': 828.3368,
#      'Thermal time increment': 14.6683,
#      'Phenology': 'repro',
#      'Plant leaf area': 1116.0267,
#      'Leaf area increment': 39.1022,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 227.001,
#      'Height increment': 2.728,
#      'Incident PAR': 6.156,
#      'Absorbed PAR': 0.1385,
#      'N demand': 0.4169,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     246: {'Date': '2018-09-03',
#      'Thermal time': 842.2031,
#      'Thermal time increment': 13.8663,
#      'Phenology': 'repro',
#      'Plant leaf area': 1145.3067,
#      'Leaf area increment': 29.28,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 230.035,
#      'Height increment': 3.034,
#      'Incident PAR': 8.5272,
#      'Absorbed PAR': 0.1453,
#      'N demand': 0.5917,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     247: {'Date': '2018-09-04',
#      'Thermal time': 857.2674,
#      'Thermal time increment': 15.0643,
#      'Phenology': 'repro',
#      'Plant leaf area': 1187.1733,
#      'Leaf area increment': 41.8667,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 232.563,
#      'Height increment': 2.528,
#      'Incident PAR': 10.1232,
#      'Absorbed PAR': 0.1499,
#      'N demand': 0.7024,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     248: {'Date': '2018-09-05',
#      'Thermal time': 871.7657,
#      'Thermal time increment': 14.4983,
#      'Phenology': 'repro',
#      'Plant leaf area': 1237.3156,
#      'Leaf area increment': 50.1422,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 234.971,
#      'Height increment': 2.408,
#      'Incident PAR': 8.7096,
#      'Absorbed PAR': 0.16,
#      'N demand': 0.6464,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     249: {'Date': '2018-09-06',
#      'Thermal time': 886.6923,
#      'Thermal time increment': 14.9266,
#      'Phenology': 'repro',
#      'Plant leaf area': 1283.8933,
#      'Leaf area increment': 46.5778,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 236.992,
#      'Height increment': 2.021,
#      'Incident PAR': 10.488,
#      'Absorbed PAR': 0.1707,
#      'N demand': 0.8036,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     250: {'Date': '2018-09-07',
#      'Thermal time': 901.1178,
#      'Thermal time increment': 14.4255,
#      'Phenology': 'repro',
#      'Plant leaf area': 1342.3111,
#      'Leaf area increment': 58.4178,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 238.802,
#      'Height increment': 1.81,
#      'Incident PAR': 9.12,
#      'Absorbed PAR': 0.1772,
#      'N demand': 0.7277,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     251: {'Date': '2018-09-08',
#      'Thermal time': 917.4671,
#      'Thermal time increment': 16.3494,
#      'Phenology': 'repro',
#      'Plant leaf area': 1395.7156,
#      'Leaf area increment': 53.4044,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 240.322,
#      'Height increment': 1.52,
#      'Incident PAR': 8.2992,
#      'Absorbed PAR': 0.1829,
#      'N demand': 0.6694,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     252: {'Date': '2018-09-09',
#      'Thermal time': 930.9049,
#      'Thermal time increment': 13.4378,
#      'Phenology': 'repro',
#      'Plant leaf area': 1445.2622,
#      'Leaf area increment': 49.5467,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 241.805,
#      'Height increment': 1.483,
#      'Incident PAR': 5.1528,
#      'Absorbed PAR': 0.194,
#      'N demand': 0.4582,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     253: {'Date': '2018-09-10',
#      'Thermal time': 944.1624,
#      'Thermal time increment': 13.2574,
#      'Phenology': 'repro',
#      'Plant leaf area': 1479.4489,
#      'Leaf area increment': 34.1867,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 242.858,
#      'Height increment': 1.053,
#      'Incident PAR': 6.0192,
#      'Absorbed PAR': 0.2046,
#      'N demand': 0.5536,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     254: {'Date': '2018-09-11',
#      'Thermal time': 958.8362,
#      'Thermal time increment': 14.6738,
#      'Phenology': 'repro',
#      'Plant leaf area': 1520.9778,
#      'Leaf area increment': 41.5289,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 243.767,
#      'Height increment': 0.909,
#      'Incident PAR': 5.5632,
#      'Absorbed PAR': 0.2177,
#      'N demand': 0.5421,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     255: {'Date': '2018-09-12',
#      'Thermal time': 971.9903,
#      'Thermal time increment': 13.154,
#      'Phenology': 'repro',
#      'Plant leaf area': 1561.9111,
#      'Leaf area increment': 40.9333,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 244.641,
#      'Height increment': 0.874,
#      'Incident PAR': 5.5632,
#      'Absorbed PAR': 0.2313,
#      'N demand': 0.5685,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     256: {'Date': '2018-09-13',
#      'Thermal time': 987.7587,
#      'Thermal time increment': 15.7684,
#      'Phenology': 'repro',
#      'Plant leaf area': 1605.0844,
#      'Leaf area increment': 43.1733,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 245.323,
#      'Height increment': 0.682,
#      'Incident PAR': 9.8496,
#      'Absorbed PAR': 0.2464,
#      'N demand': 0.9961,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     257: {'Date': '2018-09-14',
#      'Thermal time': 1004.3878,
#      'Thermal time increment': 16.6291,
#      'Phenology': 'repro',
#      'Plant leaf area': 1681.1644,
#      'Leaf area increment': 76.08,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 246.028,
#      'Height increment': 0.705,
#      'Incident PAR': 3.4656,
#      'Absorbed PAR': 0.2663,
#      'N demand': 0.4046,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     258: {'Date': '2018-09-15',
#      'Thermal time': 1015.1916,
#      'Thermal time increment': 10.8037,
#      'Phenology': 'repro',
#      'Plant leaf area': 1712.32,
#      'Leaf area increment': 31.1556,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 246.659,
#      'Height increment': 0.631,
#      'Incident PAR': 10.1688,
#      'Absorbed PAR': 0.2821,
#      'N demand': 1.0681,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     259: {'Date': '2018-09-16',
#      'Thermal time': 1030.3284,
#      'Thermal time increment': 15.1368,
#      'Phenology': 'repro',
#      'Plant leaf area': 1794.8978,
#      'Leaf area increment': 82.5778,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 247.015,
#      'Height increment': 0.356,
#      'Incident PAR': 4.8336,
#      'Absorbed PAR': 0.2919,
#      'N demand': 0.6046,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     260: {'Date': '2018-09-17',
#      'Thermal time': 1042.6154,
#      'Thermal time increment': 12.287,
#      'Phenology': 'repro',
#      'Plant leaf area': 1842.0267,
#      'Leaf area increment': 47.1289,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 247.451,
#      'Height increment': 0.436,
#      'Incident PAR': 9.7584,
#      'Absorbed PAR': 0.3116,
#      'N demand': 1.1565,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     261: {'Date': '2018-09-18',
#      'Thermal time': 1058.4381,
#      'Thermal time increment': 15.8228,
#      'Phenology': 'repro',
#      'Plant leaf area': 1932.6044,
#      'Leaf area increment': 90.5778,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 247.758,
#      'Height increment': 0.307,
#      'Incident PAR': 9.4848,
#      'Absorbed PAR': 0.3371,
#      'N demand': 1.2157,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     262: {'Date': '2018-09-19',
#      'Thermal time': 1076.6721,
#      'Thermal time increment': 18.234,
#      'Phenology': 'repro',
#      'Plant leaf area': 2028.5867,
#      'Leaf area increment': 95.9822,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 248.1,
#      'Height increment': 0.342,
#      'Incident PAR': 9.804,
#      'Absorbed PAR': 0.3483,
#      'N demand': 1.2281,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     263: {'Date': '2018-09-20',
#      'Thermal time': 1094.3732,
#      'Thermal time increment': 17.701,
#      'Phenology': 'repro',
#      'Plant leaf area': 2126.3111,
#      'Leaf area increment': 97.7244,
#      'Plant senescent leaf area': 0.0,
#      'Senescent leaf area increment': 0.0,
#      'Plant height': 248.43,
#      'Height increment': 0.33,
#      'Incident PAR': 10.1232,
#      'Absorbed PAR': 0.3787,
#      'N demand': 1.3488,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     264: {'Date': '2018-09-21',
#      'Thermal time': 1113.2024,
#      'Thermal time increment': 18.8292,
#      'Phenology': 'repro',
#      'Plant leaf area': 2234.4356,
#      'Leaf area increment': 108.1244,
#      'Plant senescent leaf area': 0.0444,
#      'Senescent leaf area increment': 0.0444,
#      'Plant height': 248.696,
#      'Height increment': 0.266,
#      'Incident PAR': 9.7584,
#      'Absorbed PAR': 0.4139,
#      'N demand': 1.3611,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     265: {'Date': '2018-09-22',
#      'Thermal time': 1132.1984,
#      'Thermal time increment': 18.996,
#      'Phenology': 'repro',
#      'Plant leaf area': 2343.8311,
#      'Leaf area increment': 109.3956,
#      'Plant senescent leaf area': 0.6667,
#      'Senescent leaf area increment': 0.6222,
#      'Plant height': 248.93,
#      'Height increment': 0.234,
#      'Incident PAR': 7.2048,
#      'Absorbed PAR': 0.4491,
#      'N demand': 1.1353,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     266: {'Date': '2018-09-23',
#      'Thermal time': 1147.3336,
#      'Thermal time increment': 15.1353,
#      'Phenology': 'repro',
#      'Plant leaf area': 2435.5822,
#      'Leaf area increment': 91.7511,
#      'Plant senescent leaf area': 1.3689,
#      'Senescent leaf area increment': 0.7022,
#      'Plant height': 249.124,
#      'Height increment': 0.194,
#      'Incident PAR': 8.0256,
#      'Absorbed PAR': 0.4828,
#      'N demand': 1.3685,
#      'Density': 11.25,
#      'Emergence': 181.0},
#     267: {'Date': '2018-09-24',
#      'Thermal time': 1163.391,
#      'Thermal time increment': 16.0574,
#      'Phenology': 'repro',
#      'Plant leaf area': 2524.1867,
#      'Leaf area increment': 88.6044,
#      'Plant senescent leaf area': 2.2222,
#      'Senescent leaf area increment': 0.8533,
#      'Plant height': 249.124,
#      'Height increment': 0.0,
#      'Incident PAR': 8.3448,
#      'Absorbed PAR': 0.5216,
#      'N demand': 1.475,
#      'Density': 11.25,
#      'Emergence': 181.0}}}}}
