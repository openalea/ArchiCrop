# %%
# Imports 

import os
from datetime import date

from openalea.widgets.plantgl import *
from openalea.plantgl.all import Material, Color3, Scene, Viewer

import sys
sys.path.append('../data')
from archi_dict import *

from openalea.archicrop.archicrop import ArchiCrop
from openalea.archicrop.display import build_scene, display_scene
from openalea.archicrop.stand import agronomic_plot, compute_domain, regular, regularband, config_crop_intercrop

# %gui qt

# %%
green = Color3((0,50,0))

# %%
cereals = ["Sorghum", "Maize", "Wheat", "Rice 1", "Rice 2"]

cereal_dict = {}

for c, archi in zip(cereals, [archi_sorghum_theo, archi_maize_theo, archi_wheat_theo, archi_rice_theo_1, archi_rice_theo_2]):
    cereal = ArchiCrop(**archi, plant_orientation=90)
    cereal.generate_potential_plant()
    cereal_dict[c] = cereal.g

sorghum = cereal_dict["Sorghum"]
maize = cereal_dict["Maize"]
wheat = cereal_dict["Wheat"]
rice_1 = cereal_dict["Rice 1"]
rice_2 = cereal_dict["Rice 2"]

# %% [markdown]
# # Wheat - Maize intercrops

# %%
crop_1 = wheat
crop_2 = maize

# %% [markdown]
# ## Strips

# %%
density_1 = 50
density_2 = 7
inter_row_1 = 0.20
inter_row_2 = 0.70
width = 8
length = 2
nb_rows_1 = 5
nb_rows_2 = 2

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %%
nb_rows_1 = 8
nb_rows_2 = 1

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %% [markdown]
# # Sorghum - Maize intercrops

# %%
crop_1 = sorghum
crop_2 = maize

# %% [markdown]
# ## Strips

# %%
density_1 = 5
density_2 = 5
inter_row_1 = 0.70
inter_row_2 = 0.70
width = 8
length = 2
nb_rows_1 = 2
nb_rows_2 = 2

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %%
nb_rows_1 = 4
nb_rows_2 = 4

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %% [markdown]
# ## Alternate rows

# %%
density_1 = 5
density_2 = 5
inter_row_1 = 0.70
inter_row_2 = 0.70
width = 8
length = 2
nb_rows_1 = 1
nb_rows_2 = 1

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %% [markdown]
# ## In-row mixture

# %%
density_1 = 5
density_2 = density_1
inter_row_1 = 0.70
inter_row_2 = inter_row_1
width = 8
length = 2
nb_rows_1 = 0
nb_rows_2 = nb_rows_1

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)

# %% [markdown]
# # Rice varietal mixture

# %%
crop_1 = rice_1
crop_2 = rice_2

# %% [markdown]
# ## In-row mixture

# %%
density_1 = 20
density_2 = density_1
inter_row_1 = 0.20
inter_row_2 = inter_row_1
width = 4
length = 2
nb_rows_1 = 0
nb_rows_2 = nb_rows_1

list_of_graphs, positions_crop = config_crop_intercrop(crop_1, crop_2, inter_row_1, inter_row_2, density_1, density_2, nb_rows_1, nb_rows_2, width, length)
scene, labels = build_scene(list_of_graphs, positions_crop, leaf_material=Material(green), stem_material=Material(green), senescence=True)
Viewer.display(scene)
